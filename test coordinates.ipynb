# %%
import cv2
from matplotlib import pyplot as plt

image = cv2.imread('wireframes\img1_1.png')
image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
import json

f = open('annotations.json')

data = json.load(f)

for i in data:
    if (i['image'] == 1 and i['shot'] == 1):
        points = i['projection']
    else: 
        continue
    
print(points)
# Out:
# [[105, 542], [286, 625], [611, 100], [430, 17], [-99, 411], [81, 494], [406, -30], [225, -113]]

# %%
img_copy = image.copy()
cv2.line(img_copy, points[0], points[1], (255,0,0), 3)
plt.imshow(img_copy)
