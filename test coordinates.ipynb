# %%
import cv2
from matplotlib import pyplot as plt

image = cv2.imread('wireframes\img2_3.png')
image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
import json

f = open('annotations.json')

data = json.load(f)

for i in data:
    if (i['image'] == 2 and i['shot'] == 3):
        points = i['projection']
    else: 
        continue

print(points)
# Out:
# [[647, -7], [-135, -7], [-135, 519], [647, 519], [647, -7], [-135, -7], [-135, 519], [647, 519]]

# %%
for i in range(len(points)):
    cv2.circle(image, points[i], radius=3, color=(255,0,0))

plt.imshow(image)
