# %%
import cv2
from matplotlib import pyplot as plt

image = cv2.imread('wireframes\img1_1.png')
image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
import json

f = open('annotations.json')

data = json.load(f)

for i in data:
    if (i['image'] == 1 and i['shot'] == 1):
        points = i['projection']
    else: 
        continue
    
print(points)

edges = (
            (0, 1),
            (1, 2),
            (2, 3),
            (3, 0),
            (4, 5),
            (5, 6),
            (6, 7),
            (7, 4),
            (0, 4),
            (1, 5),
            (2, 6),
            (3, 7)
        )
# Out:
# [[288, 203], [312, 239], [320, 345], [271, 329], [301, 319], [265, 300], [280, 215], [301, 242]]

# %%
img_copy = image.copy()
for i in edges:
    x = points[i[0]]
    y = points[i[1]]
    cv2.line(img_copy, (x[0], x[1]-512) , (y[0], y[1]-512), (255,0,0), 3)
plt.imshow(img_copy)
# Out:
# [288, 203] [312, 239]
# [312, 239] [320, 345]
# [320, 345] [271, 329]
# [271, 329] [288, 203]
# [301, 319] [265, 300]
# [265, 300] [280, 215]
# [280, 215] [301, 242]
# [301, 242] [301, 319]
# [288, 203] [301, 319]
# [312, 239] [265, 300]
# [320, 345] [280, 215]
# [271, 329] [301, 242]
